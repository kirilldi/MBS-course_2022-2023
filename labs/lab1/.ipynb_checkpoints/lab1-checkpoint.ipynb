# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Задание 1

# %%
m = np.random.uniform(size=(10,2))

# %%
print(m)
# Out:
# [[0.55361853 0.84459443]
#  [0.91793175 0.81666156]
#  [0.64793522 0.27496713]
#  [0.59198553 0.54460424]
#  [0.38668047 0.00556025]
#  [0.45847661 0.04154097]
#  [0.79707714 0.61036937]
#  [0.74783706 0.60732844]
#  [0.01330475 0.37764542]
#  [0.34311638 0.66227214]]

# %% [markdown]
# # Задание 2

# %%
plt.figure(dpi=100)
plt.plot(m[:,0],m[:,1],'ok')

# %%
# pois(lbd,n_points)
dst = np.random.poisson(5,1000)
plt.hist(dst,density=True,histtype='stepfilled')
plt.title('Poisson')
# Out:
# Text(0.5, 1.0, 'Poisson')

# %%
print('mean',np.mean(dst))
print('var',np.var(dst))
# Out:
# mean 4.874
# var 4.772124

# %% [markdown]
# # Задание три

# %%
a = 1
point = np.random.uniform(size=(1,2))
print(point)
plt.plot(point[:,0],point[:,1],'ok')
plt.axis([0, a, 0, a])
# Out:
# [[0.28765528 0.44929251]]
# (0.0, 1.0, 0.0, 1.0)
