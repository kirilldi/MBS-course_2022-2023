# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Задание 1

# %%
m = np.random.uniform(size=(10,2))

# %%
print(m)
# Out:
# [[0.52787006 0.44501718]
#  [0.398002   0.67354216]
#  [0.05446258 0.61616531]
#  [0.33409294 0.75872734]
#  [0.78875236 0.42959645]
#  [0.37579406 0.60181662]
#  [0.39278326 0.52995785]
#  [0.22056608 0.84210149]
#  [0.20046115 0.76950321]
#  [0.83326597 0.49923856]]

# %% [markdown]
# # Задание 2

# %%
plt.figure(dpi=100)
plt.plot(m[:,0],m[:,1],'ok')

# %%
# pois(lbd,n_points)
dst = np.random.poisson(5,1000)
plt.hist(dst,density=True,histtype='stepfilled')
plt.title('Poisson')
# Out:
# Text(0.5, 1.0, 'Poisson')

# %%
print('mean',np.mean(dst))
print('var',np.var(dst))
# Out:
# mean 4.874
# var 4.772124

# %% [markdown]
# # Задание три

# %%
a = 1
point = np.random.uniform(size=(1,2))
print(point)
plt.plot(point[:,0],point[:,1],'ok')
plt.axis([0, a, 0, a])
# Out:
# [[0.28765528 0.44929251]]
# (0.0, 1.0, 0.0, 1.0)
